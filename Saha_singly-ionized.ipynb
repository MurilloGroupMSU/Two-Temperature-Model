# %% [markdown]
# # Saha code

# %% [markdown]
# Based on paper by [Seungtaek](https://iopscience.iop.org/article/10.1088/1361-6587/ac7ee8/pdf)
#
# #### Ionization Potential Depression (from continuum lowering)
# We assume some average ionization level $\bar{Z} \equiv n_e/n_0$ and also that the ionization is lower than 1 for simplicity.
#
# In atomic units, we have
# $$
# \Delta \chi = (\bar{Z} + 1)\sqrt{4 \pi \frac{\bar{Z} (\bar{Z}+1)n_0}{T_e}}
# $$
# Then the Saha equation is in the singly ionized limit is
# $$
# \frac{\bar{Z}^2 }{1-\bar{Z}} = \frac{2 g_1}{n_0 g_0} \left(\frac{m_e T_e}{2 \pi}\right)^{3/2} \exp \left[\beta (\chi_0 - \Delta \chi )\right].
# $$
# Where $g_0$ and $g_1$ are the degeneracy parameters for neutral and singly ionized species.
#
# #### Argon
# For argon this is $g_0=1$, and $g_1\approx 6$, which comes from the fact that S=1/2, L=1, so J={1/2, 3/2}, giving 2 + 4 = 6 total states that are approximately degenerate.
#
# #### Xenon
# I think it should be the same, as long as d-orbitals don't play a role...
#
#
# For ionization energies, see [NIST](https://physics.nist.gov/cgi-bin/ASD/ie.pl?spectra=Xe&units=1&at_num_out=on&el_name_out=on&seq_out=on&shells_out=on&level_out=on&e_out=0&unc_out=on&biblio=on)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from cycler import cycler


mpl.rcParams['lines.linewidth'] = 2.2
mpl.rcParams['axes.spines.right'] = True
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['lines.markersize'] = 8
mpl.rcParams['font.sans-serif'] = ['Arial', 'Tahoma', 'DejaVu Sans', 'Lucida Grande', 'Verdana']
mpl.rcParams['font.size'] = 12
mpl.rcParams['axes.grid'] = True
mpl.rcParams['grid.color'] = '#636363'
mpl.rcParams['grid.alpha'] = 0.12
mpl.rcParams['grid.linewidth'] = 0.7
mpl.rcParams['grid.linestyle'] = '-'
mpl.rcParams['axes.prop_cycle'] = cycler('color',  ['#0AB34F', '#bf009f', '#00abc3', '#8e92c5', '#cc7014', '#e32851'])
mpl.rcParams['legend.fancybox'] = True
mpl.rcParams['legend.framealpha'] = 0.6
mpl.rcParams['legend.fontsize'] = 10
mpl.rcParams['figure.figsize'] = 8, 4.9443
mpl.rcParams['figure.dpi'] = 100

from hnc.hnc.constants import *

# %%
from scipy.optimize import root, least_squares

@np.vectorize
def Δχ_func(Zbar, n0, Te): # in AU 
    return np.min( [ (Zbar+1) * np.sqrt(4*π * Zbar*(Zbar+1)*n0/Te) , χ0_AU] )

def leftminusright_saha(Zbar, n0, Te):
    Δχ = Δχ_func(Zbar, n0, Te)
    left_hand_side = Zbar**2/(1 - Zbar) 
    right_hand_side = 2/n0 * g1/g0 * (m_e*Te/(2*π))**(3/2) * np.exp( -(χ0_AU - Δχ)/Te )
    return left_hand_side - right_hand_side

def leftminusrightsquare_saha(Zbar, n0, Te):
    Δχ = Δχ_func(Zbar, n0, Te)
    left_hand_side = Zbar**2/(1 - Zbar) 
    right_hand_side = 2/n0 * g1/g0 * (m_e*Te/(2*π))**(3/2) * np.exp( -(χ0_AU - Δχ)/Te )
    return (left_hand_side - right_hand_side)**2


@np.vectorize
def solve_Saha(Te, n0, Zbar_0=0.5):
    saha_LR = lambda Zbar: leftminusrightsquare_saha(Zbar, n0, Te) 
    ε = 1e-2
    sol =  least_squares(saha_LR, Zbar_0, bounds=(0,1), ftol=1e-10, xtol=1e-8, gtol=None, max_nfev = 1000)
    if sol.cost > 1e-8 or sol.success==False or sol.x<1e-10: #sol.grad > 1e-8 or sol.fun > 1e-8: 
        print(f"{sol.success}: Te={Te:0.3f}, n0={n0:0.1e}, Zbar_0={Zbar_0:0.3f}")
        print(sol)
        return np.nan, np.nan, sol
    return sol.x, Δχ_func(sol.x, n0, Te)#, sol

# %% [markdown]
# ### Xenon at single density

# %%
element='Xe'
g1 = 6 
g0 = 1
χ0_eV = 12.1298437  # eV See 
χ0_AU = χ0_eV*eV_to_AU

n0_invcc = 1.6*1.25e20 
n0_AU = n0_invcc*invcc_to_AU

# array
T_K_array = np.geomspace(5e3, 3e4, num=100)
Zbar_0_list = np.linspace(5e-6,1-1e-6, num=10)
Saha_list = [ solve_Saha(T_K_array*K_to_AU, n0_AU, Zbar_0=Zbar_0) for Zbar_0 in Zbar_0_list]
# Out:
# True: Te=0.019, n0=3.0e-05, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.363e-17]
#            x: [ 4.941e-324]
#         cost: 9.51838453080155e-34
#          jac: [[ 5.141e-12]]
#         grad: [ 2.243e-28]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.050, n0=3.0e-05, Zbar_0=0.111
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.218e-03]
#            x: [ 4.941e-324]
#         cost: 7.419440401112119e-07
#          jac: [[ 3.496e+01]]
#         grad: [ 4.259e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 9
#         njev: 8
# True: Te=0.053, n0=3.0e-05, Zbar_0=0.222
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.322e-03]
#            x: [ 8.772e-29]
#         cost: 1.4160536955010357e-05
#          jac: [[ 1.370e+02]]
#         grad: [ 7.291e-01]
#   optimality: 6.396208047058736e-29
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# True: Te=0.055, n0=3.0e-05, Zbar_0=0.333
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.076e-02]
#            x: [ 4.941e-324]
#         cost: 5.787520502867402e-05
#          jac: [[ 2.623e+02]]
#         grad: [ 2.822e+00]
#   optimality: 1.5e-323
#  active_mask: [-1]
#         nfev: 10
#         njev: 10
# True: Te=0.056, n0=3.0e-05, Zbar_0=0.444
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.518e-02]
#            x: [ 4.941e-324]
#         cost: 0.00011515004270405468
#          jac: [[ 3.601e+02]]
#         grad: [ 5.465e+00]
#   optimality: 2.5e-323
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# True: Te=0.057, n0=3.0e-05, Zbar_0=0.556
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.129e-02]
#            x: [ 4.941e-324]
#         cost: 0.00022673722422287786
#          jac: [[ 4.918e+02]]
#         grad: [ 1.047e+01]
#   optimality: 5e-323
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# True: Te=0.059, n0=3.0e-05, Zbar_0=0.667
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.130e-02]
#            x: [ 4.941e-324]
#         cost: 0.0008527545940531902
#          jac: [[ 9.034e+02]]
#         grad: [ 3.731e+01]
#   optimality: 1.83e-322
#  active_mask: [-1]
#         nfev: 11
#         njev: 11
# True: Te=0.066, n0=3.0e-05, Zbar_0=0.778
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.684e-01]
#            x: [ 1.097e-30]
#         cost: 0.03602010452548608
#          jac: [[ 4.989e+03]]
#         grad: [ 1.339e+03]
#   optimality: 1.4688439729134096e-27
#  active_mask: [-1]
#         nfev: 10
#         njev: 10

# %%
# Fix nan, None issues...

Zbar_list = np.array([Saha[0] for Saha in Saha_list])
χ0_list   = np.array([Saha[1] for Saha in Saha_list])
Zbar_mean, Zbar_std = np.nanmean(Zbar_list,axis=0), np.nanstd(Zbar_list,axis=0) 
χ0_mean, χ0_std = np.nanmean(χ0_list,axis=0), np.nanstd(χ0_list,axis=0)

# %%
fig, ax = plt.subplots(figsize=(10,6))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

ax.set_ylabel(r"$\langle Z \rangle$",color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
ax2.set_ylabel(r"$\Delta \chi$ [eV]",color=colors[1])

# Plot mean and Std
ax.plot(T_K_array, Zbar_mean,'-' , color=colors[0])#, label=f'Initial guess')
ax.fill_between(T_K_array, Zbar_mean - Zbar_std, Zbar_mean + Zbar_std, color=colors[0], alpha=0.2)
ax2.plot(T_K_array, χ0_mean*AU_to_eV,'-' , color=colors[1])#, label=r'$\chi_0$')
ax2.fill_between(T_K_array, (χ0_mean - χ0_std)*AU_to_eV, (χ0_mean + χ0_std)*AU_to_eV, color=colors[1], alpha=0.2, linestyle='-')
           

# Plot all actual solution output    
colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i], label=f'Solution for colorbar initial guess', alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i], label=r'$\chi_0$', alpha=0.1, markersize=5)
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i],alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i],alpha=0.1, markersize=5)
        except TypeError:
            pass


# Plot χ0 Line
ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Plot Zbar=1 Line
ax.plot(T_K_array, np.ones_like(T_K_array),'-' ,color='k')
ax.text(np.min(T_K_array)*1.2, 1.1, r"$\langle Z \rangle$ = 1", fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.55, 0.25, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-7,2)
ax2.set_ylim(1e-3,10*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend(loc='lower right')
# plt.tight_layout()
# ax.set_yscale('log')

# %% [markdown]
# ### Xenon Mesh for Interpolation

# %%
element='Xe'
g1 = 6 
g0 = 1
χ0_eV = 12.1298437  # eV See 
χ0_AU = χ0_eV*eV_to_AU

# Ion density
n0_invcc_array = 1.25e20*np.geomspace(0.5,1.5,num=20) 

# Temperature
T_K_array = np.geomspace(5e3, 3e4, num=100)

n_invcc_mesh, T_K_mesh = np.meshgrid(n0_invcc_array, T_K_array, indexing='ij')

Zbar_0_list = np.linspace(5e-6,1-1e-6, num=10)
Saha_array = np.array([ solve_Saha(T_K_mesh*K_to_AU, n_invcc_mesh*invcc_to_AU, Zbar_0=Zbar_0) for Zbar_0 in Zbar_0_list] )
# Out:
# True: Te=0.019, n0=9.3e-06, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.822e-16]
#            x: [ 2.276e-28]
#         cost: 1.659821562046836e-32
#          jac: [[ 1.233e-11]]
#         grad: [ 2.246e-27]
#   optimality: 5.111264442567301e-55
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.048, n0=9.3e-06, Zbar_0=0.111
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.763e-03]
#            x: [ 4.941e-324]
#         cost: 1.660520704319175e-05
#          jac: [[ 9.760e+01]]
#         grad: [ 5.625e-01]
#   optimality: 5e-324
#  active_mask: [-1]
#         nfev: 7
#         njev: 7
# True: Te=0.052, n0=9.3e-06, Zbar_0=0.222
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.801e-02]
#            x: [ 2.342e-31]
#         cost: 0.0007225518088461207
#          jac: [[ 5.621e+02]]
#         grad: [ 2.137e+01]
#   optimality: 5.0043562578386354e-30
#  active_mask: [-1]
#         nfev: 9
#         njev: 8
# True: Te=0.055, n0=9.3e-06, Zbar_0=0.333
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.102e-01]
#            x: [ 5.864e-29]
#         cost: 0.006068655098814864
#          jac: [[ 1.502e+03]]
#         grad: [ 1.654e+02]
#   optimality: 9.701463545929573e-27
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# True: Te=0.057, n0=9.3e-06, Zbar_0=0.444
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.181e-01]
#            x: [ 4.941e-324]
#         cost: 0.023775121162672833
#          jac: [[ 2.815e+03]]
#         grad: [ 6.139e+02]
#   optimality: 3.034e-321
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# True: Te=0.060, n0=9.3e-06, Zbar_0=0.556
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.846e-01]
#            x: [ 3.605e-30]
#         cost: 0.17085356864409312
#          jac: [[ 6.956e+03]]
#         grad: [ 4.066e+03]
#   optimality: 1.4660367164202362e-26
#  active_mask: [-1]
#         nfev: 9
#         njev: 9
# True: Te=0.065, n0=9.3e-06, Zbar_0=0.667
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.035e+00]
#            x: [ 1.420e-33]
#         cost: 2.071064886396307
#          jac: [[ 2.173e+04]]
#         grad: [ 4.422e+04]
#   optimality: 6.277616337519948e-29
#  active_mask: [-1]
#         nfev: 10
#         njev: 10
# True: Te=0.074, n0=9.3e-06, Zbar_0=0.778
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.524e+01]
#            x: [ 9.403e-30]
#         cost: 116.06247831712506
#          jac: [[ 1.345e+05]]
#         grad: [ 2.049e+06]
#   optimality: 1.9268075094211986e-23
#  active_mask: [-1]
#         nfev: 9
#         njev: 9

# %%
# Fix nan, None issues...

Zbar_list = Saha_array[:,0]#np.array([Saha[0] for Saha in Saha_list])
χ0_list   = Saha_array[:,1]#np.array([Saha[1] for Saha in Saha_list])
Zbar_mean, Zbar_std = np.nanmean(Zbar_list,axis=0), np.nanstd(Zbar_list,axis=0) 
χ0_mean, χ0_std = np.nanmean(χ0_list,axis=0), np.nanstd(χ0_list,axis=0)

# %%
mesh_save_data = np.array( [ n_invcc_mesh.flatten(), T_K_mesh.flatten(), Zbar_mean.flatten(), Zbar_std.flatten(), χ0_mean.flatten()*AU_to_eV, χ0_std.flatten()*AU_to_eV ]).T
header = ("# Shown is also the standard deviation from a large set of initial guesses, if large then invalid- multiple solutions \n" + 
            "   n[1/cc]      T[K]         Zbar         σ(Zbar)      χ0[eV]       σ(χ0[eV])")
savename = "Xenon_5bar_Saha_solution_data.txt"
np.savetxt(savename, mesh_save_data, header = header , fmt ="%12.3e", comments='')

# %%
from pandas import read_csv
N_n, N_T = 20, 100
saved_data = read_csv(savename, delim_whitespace=True, header=1)
n_invm3_mesh = np.array(saved_data['n[1/cc]']).reshape(N_n, N_T)*1e6
T_K_mesh     = np.array(saved_data['T[K]']).reshape(N_n, N_T)
Zbar_mesh    = np.array(saved_data['Zbar']).reshape(N_n, N_T)
χ0_J_mesh    = np.array(saved_data['χ0[eV]']).reshape(N_n, N_T)*eV_to_K

# %%
from scipy.interpolate import RegularGridInterpolator

zbar_interp = RegularGridInterpolator((n_invm3_mesh[:,0],T_K_mesh[0,:]), Zbar_mesh, bounds_error=False)
zbar_interp((1.875e26, 4e3))
# Out:
# array(nan)

# %%
i,j = -1, -1
n_invm3_mesh[i,j], T_K_mesh[i,j], χ0_J_mesh[i,j]
# Out:
# (1.875e+26, 30000.0, 52638.125427940846)

# %%
i,j = 0, 0
n_invm3_mesh[i,j], T_K_mesh[i,j], χ0_J_mesh[i,j]
# Out:
# (6.25e+25, 5000.0, 85.39769952032997)

# %%
fig, ax = plt.subplots()
 
ax.contourf(n_invm3_mesh,T_K_mesh, χ0_J_mesh )


ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r"$n$ [1/m$^3$]")
ax.set_ylabel("T[K]")
# Out:
# Text(0, 0.5, 'T[K]')

# %%
element='Ar'
g1 = 5.66 #6 
g0 = 1
χ0_eV = 15.8 # eV
χ0_AU = χ0_eV*eV_to_AU

n0_invcc = 2.53e21#6.3e26/1e6
n0_AU = n0_invcc*invcc_to_AU

# array
T_K_array = np.geomspace(1e3, 3e4, num=100)
Zbar_0_list = np.linspace(1e-6,1-1e-6, num=20)
Saha_list = [ solve_Saha(T_K_array*K_to_AU, n0_AU, Zbar_0=Zbar_0) for Zbar_0 in Zbar_0_list]
# Out:
# True: Te=0.024, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.353e-20]
#            x: [ 4.941e-324]
#         cost: 1.4329558758106666e-39
#          jac: [[ 1.618e-14]]
#         grad: [ 8.663e-34]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.025, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.033e-19]
#            x: [ 5.946e-28]
#         cost: 4.6003920112239647e-38
#          jac: [[ 8.709e-14]]
#         grad: [ 2.642e-32]
#   optimality: 1.5707442380898165e-59
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.026, n0=3.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.627e-18]
#            x: [ 8.968e-44]
#         cost: 1.3228192110710617e-36
#          jac: [[ 4.436e-13]]
#         grad: [ 7.215e-31]
#   optimality: 6.470241474977879e-74
#  active_mask: [-1]
#         nfev: 6
#         njev: 6
# True: Te=0.027, n0=3.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 8.270e-18]
#            x: [ 4.941e-324]
#         cost: 3.4195265914136863e-35
#          jac: [[ 2.142e-12]]
#         grad: [ 1.771e-29]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 6
#         njev: 6
# True: Te=0.028, n0=3.7e-04, Zbar_0=0.000
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.994e-17]
#            x: [ 4.941e-324]
#         cost: 7.97540860330359e-34
#          jac: [[ 9.823e-12]]
#         grad: [ 3.923e-28]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 6
#         njev: 6
# True: Te=0.029, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.835e-16]
#            x: [ 1.083e-27]
#         cost: 1.6841092139345947e-32
#          jac: [[ 4.287e-11]]
#         grad: [ 7.868e-27]
#   optimality: 8.519456427952819e-54
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.030, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 8.038e-16]
#            x: [ 2.472e-27]
#         cost: 3.2305453533568936e-31
#          jac: [[ 1.783e-10]]
#         grad: [ 1.433e-25]
#   optimality: 3.543117761803491e-52
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.031, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 3.361e-15]
#            x: [ 1.910e-27]
#         cost: 5.6477882487739305e-30
#          jac: [[ 7.081e-10]]
#         grad: [ 2.380e-24]
#   optimality: 4.544738917010795e-51
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.032, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.344e-14]
#            x: [ 4.941e-324]
#         cost: 9.0269088665824e-29
#          jac: [[ 2.688e-09]]
#         grad: [ 3.612e-23]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.033, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.144e-14]
#            x: [ 6.170e-28]
#         cost: 1.3230399227533532e-27
#          jac: [[ 9.774e-09]]
#         grad: [ 5.028e-22]
#   optimality: 3.1021170704884103e-49
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.034, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.889e-13]
#            x: [ 4.941e-324]
#         cost: 1.7834084219066726e-26
#          jac: [[ 3.408e-08]]
#         grad: [ 6.437e-21]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.035, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 6.659e-13]
#            x: [ 4.396e-28]
#         cost: 2.2171775295946334e-25
#          jac: [[ 1.141e-07]]
#         grad: [ 7.600e-20]
#   optimality: 3.3408977815823164e-47
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.036, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.258e-12]
#            x: [ 4.941e-324]
#         cost: 2.5492255800814774e-24
#          jac: [[ 3.675e-07]]
#         grad: [ 8.298e-19]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.038, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.373e-12]
#            x: [ 4.941e-324]
#         cost: 2.717818796713022e-23
#          jac: [[ 1.140e-06]]
#         grad: [ 8.402e-18]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.039, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.321e-11]
#            x: [ 4.941e-324]
#         cost: 2.6936721347206604e-22
#          jac: [[ 3.407e-06]]
#         grad: [ 7.909e-17]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.040, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.054e-11]
#            x: [ 3.874e-29]
#         cost: 2.488004401366616e-21
#          jac: [[ 9.835e-06]]
#         grad: [ 6.938e-16]
#   optimality: 2.6875346693559943e-44
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.042, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 2.072e-10]
#            x: [ 4.941e-324]
#         cost: 2.1467118690759562e-20
#          jac: [[ 2.744e-05]]
#         grad: [ 5.685e-15]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.043, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.889e-10]
#            x: [ 4.941e-324]
#         cost: 1.7342499056945203e-19
#          jac: [[ 7.406e-05]]
#         grad: [ 4.362e-14]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.045, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.622e-09]
#            x: [ 1.814e-31]
#         cost: 1.3147109342965258e-18
#          jac: [[ 1.937e-04]]
#         grad: [ 3.140e-13]
#   optimality: 5.697489564425269e-44
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.046, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 4.330e-09]
#            x: [ 3.183e-28]
#         cost: 9.372647972839655e-18
#          jac: [[ 4.911e-04]]
#         grad: [ 2.126e-12]
#   optimality: 6.76767077702548e-40
#  active_mask: [-1]
#         nfev: 5
#         njev: 5
# True: Te=0.048, n0=3.7e-04, Zbar_0=0.000
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1
-07
#          jac: [[ 4.653e+01]]
#         grad: [ 4.355e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 23
#         njev: 23
# True: Te=0.083, n0=3.7e-04, Zbar_0=0.737
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.694e-03]
#            x: [ 3.368e-28]
#         cost: 1.434748244681167e-06
#          jac: [[ 7.997e+01]]
#         grad: [ 1.355e-01]
#   optimality: 4.5623364522793875e-29
#  active_mask: [-1]
#         nfev: 22
#         njev: 22
# True: Te=0.086, n0=3.7e-04, Zbar_0=0.737
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.015e-03]
#            x: [ 9.125e-32]
#         cost: 4.5465481028446755e-06
#          jac: [[ 1.352e+02]]
#         grad: [ 4.077e-01]
#   optimality: 3.7203825742051327e-32
#  active_mask: [-1]
#         nfev: 22
#         njev: 22
# True: Te=0.089, n0=3.7e-04, Zbar_0=0.737
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.283e-03]
#            x: [ 4.514e-36]
#         cost: 1.3953867657421278e-05
#          jac: [[ 2.250e+02]]
#         grad: [ 1.188e+00]
#   optimality: 5.3647233839257804e-36
#  active_mask: [-1]
#         nfev: 21
#         njev: 21
# True: Te=0.092, n0=3.7e-04, Zbar_0=0.737
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.113e-03]
#            x: [ 8.466e-28]
#         cost: 4.152248482967702e-05
#          jac: [[ 3.686e+02]]
#         grad: [ 3.359e+00]
#   optimality: 2.8437108733268082e-27
#  active_mask: [-1]
#         nfev: 20
#         njev: 20
# True: Te=0.095, n0=3.7e-04, Zbar_0=0.737
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.549e-02]
#            x: [ 3.313e-30]
#         cost: 0.00011992268828125803
#          jac: [[ 5.949e+02]]
#         grad: [ 9.214e+00]
#   optimality: 3.052334763223241e-29
#  active_mask: [-1]
#         nfev: 20
#         njev: 20
# True: Te=0.070, n0=3.7e-04, Zbar_0=0.789
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 7.305e-05]
#            x: [ 8.126e-29]
#         cost: 2.6683527868511393e-09
#          jac: [[ 4.463e+00]]
#         grad: [ 3.260e-04]
#   optimality: 2.6492641522363714e-32
#  active_mask: [-1]
#         nfev: 27
#         njev: 27
# True: Te=0.072, n0=3.7e-04, Zbar_0=0.789
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.421e-04]
#            x: [ 4.941e-324]
#         cost: 1.009830045295713e-08
#          jac: [[ 8.246e+00]]
#         grad: [ 1.172e-03]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 26
#         njev: 26
# True: Te=0.075, n0=3.7e-04, Zbar_0=0.789
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.713e-04]
#            x: [ 6.207e-33]
#         cost: 3.6792242377813653e-08
#          jac: [[ 1.495e+01]]
#         grad: [ 4.055e-03]
#   optimality: 2.5171470972544957e-35
#  active_mask: [-1]
#         nfev: 26
#         njev: 26
# True: Te=0.077, n0=3.7e-04, Zbar_0=0.789
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 5.084e-04]
#            x: [ 4.941e-324]
#         cost: 1.2921838141849449e-07
#          jac: [[ 2.661e+01]]
#         grad: [ 1.353e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 25
#         njev: 25
# True: Te=0.080, n0=3.7e-04, Zbar_0=0.789
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.360e-04]
#            x: [ 5.405e-29]
#         cost: 4.3801676183022427e-07
#          jac: [[ 4.653e+01]]
#         grad: [ 4.355e-02]
#   optimality: 2.3535810876731736e-30
#  active_mask: [-1]
#         nfev: 24
#         njev: 24
# True: Te=0.083, n0=3.7e-04, Zbar_0=0.789
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.694e-03]
#            x: [ 1.448e-30]
#         cost: 1.4347482446808911e-06
#          jac: [[ 7.997e+01]]
#         grad: [ 1.355e-01]
#   optimality: 1.96101145135601e-31
#  active_mask: [-1]
#         nfev: 23
#         njev: 23
# True: Te=0.086, n0=3.7e-04, Zbar_0=0.789
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.015e-03]
#            x: [ 4.941e-324]
#         cost: 4.546548102844662e-06
#          jac: [[ 1.352e+02]]
#         grad: [ 4.077e-01]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 23
#         njev: 23
# True: Te=0.089, n0=3.7e-04, Zbar_0=0.789
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.283e-03]
#            x: [ 3.395e-29]
#         cost: 1.3953867657422113e-05
#          jac: [[ 2.250e+02]]
#         grad: [ 1.188e+00]
#   optimality: 4.0347009388628904e-29
#  active_mask: [-1]
#         nfev: 22
#         njev: 22
# True: Te=0.092, n0=3.7e-04, Zbar_0=0.789
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.113e-03]
#            x: [ 6.211e-30]
#         cost: 4.152248482966626e-05
#          jac: [[ 3.686e+02]]
#         grad: [ 3.359e+00]
#   optimality: 2.0861235427970105e-29
#  active_mask: [-1]
#         nfev: 21
#         njev: 21
# True: Te=0.095, n0=3.7e-04, Zbar_0=0.789
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.549e-02]
#            x: [ 6.213e-31]
#         cost: 0.00011992268828125674
#          jac: [[ 5.949e+02]]
#         grad: [ 9.214e+00]
#   optimality: 5.72470326023046e-30
#  active_mask: [-1]
#         nfev: 21
#         njev: 21
# True: Te=0.075, n0=3.7e-04, Zbar_0=0.842
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 2.713e-04]
#            x: [ 4.941e-324]
#         cost: 3.6792242377813653e-08
#          jac: [[ 1.495e+01]]
#         grad: [ 4.055e-03]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 27
#         njev: 27
# True: Te=0.077, n0=3.7e-04, Zbar_0=0.842
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.084e-04]
#            x: [ 4.941e-324]
#         cost: 1.2921838141849449e-07
#          jac: [[ 2.661e+01]]
#         grad: [ 1.353e-02]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 26
#         njev: 26
# True: Te=0.080, n0=3.7e-04, Zbar_0=0.842
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.360e-04]
#            x: [ 1.914e-29]
#         cost: 4.3801676183021035e-07
#          jac: [[ 4.653e+01]]
#         grad: [ 4.355e-02]
#   optimality: 8.333538240840146e-31
#  active_mask: [-1]
#         nfev: 25
#         njev: 25
# True: Te=0.083, n0=3.7e-04, Zbar_0=0.842
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.694e-03]
#            x: [ 4.941e-324]
#         cost: 1.4347482446808657e-06
#          jac: [[ 7.997e+01]]
#         grad: [ 1.355e-01]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 24
#         njev: 24
# True: Te=0.086, n0=3.7e-04, Zbar_0=0.842
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.015e-03]
#            x: [ 4.941e-324]
#         cost: 4.546548102844662e-06
#          jac: [[ 1.352e+02]]
#         grad: [ 4.077e-01]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 24
#         njev: 24
# True: Te=0.089, n0=3.7e-04, Zbar_0=0.842
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 5.283e-03]
#            x: [ 1.996e-29]
#         cost: 1.3953867657421866e-05
#          jac: [[ 2.250e+02]]
#         grad: [ 1.188e+00]
#   optimality: 2.3719410150677255e-29
#  active_mask: [-1]
#         nfev: 23
#         njev: 23
# True: Te=0.092, n0=3.7e-04, Zbar_0=0.842
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.113e-03]
#            x: [ 2.845e-28]
#         cost: 4.1522484829672e-05
#          jac: [[ 3.686e+02]]
#         grad: [ 3.359e+00]
#   optimality: 9.557554826945294e-28
#  active_mask: [-1]
#         nfev: 22
#         njev: 22
# True: Te=0.095, n0=3.7e-04, Zbar_0=0.842
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 1.549e-02]
#            x: [ 1.374e-33]
#         cost: 0.00011992268828125592
#          jac: [[ 5.949e+02]]
#         grad: [ 9.214e+00]
#   optimality: 1.2660726068487142e-32
#  active_mask: [-1]
#         nfev: 22
#         njev: 22
# True: Te=0.086, n0=3.7e-04, Zbar_0=0.895
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 3.015e-03]
#            x: [ 4.941e-324]
#         cost: 4.546548102844662e-06
#          jac: [[ 1.352e+02]]
#         grad: [ 4.077e-01]
#   optimality: 0.0
#  active_mask: [-1]
#         nfev: 25
#         njev: 25
# True: Te=0.089, n0=3.7e-04, Zbar_0=0.895
#      message: Both `ftol` and `xtol` termination conditions are satisfied.
#      success: True
#       status: 4
#          fun: [ 5.283e-03]
#            x: [ 1.078e-30]
#         cost: 1.3953867657421417e-05
#          jac: [[ 2.250e+02]]
#         grad: [ 1.188e+00]
#   optimality: 1.281426384487782e-30
#  active_mask: [-1]
#         nfev: 24
#         njev: 24
# True: Te=0.092, n0=3.7e-04, Zbar_0=0.895
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 9.113e-03]
#            x: [ 1.013e-28]
#         cost: 4.152248482966949e-05
#          jac: [[ 3.686e+02]]
#         grad: [ 3.359e+00]
#   optimality: 3.4011671964743795e-28
#  active_mask: [-1]
#         nfev: 23
#         njev: 23
# True: Te=0.095, n0=3.7e-04, Zbar_0=0.895
#      message: `xtol` termination condition is satisfied.
#      success: True
#       status: 3
#          fun: [ 1.549e-02]
#            x: [ 1.941e-27]
#         cost: 0.00011992268828130537
#          jac: [[ 5.949e+02]]
#         grad: [ 9.214e+00]
#   optimality: 1.7883623418431722e-26
#  active_mask: [-1]
#         nfev: 22
#         njev: 22

# %%
fig, ax = plt.subplots(figsize=(10,6))

# colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))



ax.set_ylabel(r"$\langle Z \rangle$")#,color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
# ax2.plot(T_K_array, Δχ_Saha*AU_to_eV,'--.',color=colors[1])
ax2.set_ylabel(r"$\Delta \chi$ [eV]")#,color=colors[1])

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'-' , color=colors[i], label=f'Initial guess, Zbar= {Zbar_0:0.3f}')
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'--' , color=colors[i], label=r'$\chi_0$')
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'-' , color=colors[i])#, label=f'Initial guess, Zbar= {Zbar_0:0.3f}')
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'--' , color=colors[i])
        except TypeError:
            pass
            
# ax2.plot(T_K_array, Δχ_Saha_1*AU_to_eV,'-' ,color=colors[1])

ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.15, 0.95, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-4,1.2)
ax2.set_ylim(1e-4,1.2*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend()
# plt.tight_layout()

# ax.set_yscale('log')

# %%
# Fix nan, None issues...

Zbar_list = np.array([Saha[0] for Saha in Saha_list])
χ0_list   = np.array([Saha[1] for Saha in Saha_list])
Zbar_mean, Zbar_std = np.nanmean(Zbar_list,axis=0), np.nanstd(Zbar_list,axis=0) 
χ0_mean, χ0_std = np.nanmean(χ0_list,axis=0), np.nanstd(χ0_list,axis=0)

# %%
fig, ax = plt.subplots(figsize=(10,6))

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

ax.set_ylabel(r"$\langle Z \rangle$",color=colors[0])
ax.set_xlabel("T [K]")
ax.set_xscale('log')

ax2 = ax.twinx()
ax2.set_ylabel(r"$\Delta \chi$ [eV]",color=colors[1])

# Plot mean and Std
ax.plot(T_K_array, Zbar_mean,'-' , color=colors[0])#, label=f'Initial guess')
ax.fill_between(T_K_array, Zbar_mean - Zbar_std, Zbar_mean + Zbar_std, color=colors[0], alpha=0.2)
ax2.plot(T_K_array, χ0_mean*AU_to_eV,'-' , color=colors[1])#, label=r'$\chi_0$')
ax2.fill_between(T_K_array, (χ0_mean - χ0_std)*AU_to_eV, (χ0_mean + χ0_std)*AU_to_eV, color=colors[1], alpha=0.2, linestyle='-')
           

# Plot all actual solution output    
colors = plt.cm.plasma(np.linspace(0, 1,len(Saha_list))) #plt.cycler("color", plt.cm.jet(np.linspace(0,1,len(Saha_list))))

for i, (Zbar_0, Saha) in enumerate(zip(Zbar_0_list, Saha_list)):
    if i==0:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i], label=f'Solution for colorbar initial guess', alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i], label=r'$\chi_0$', alpha=0.1, markersize=5)
        except TypeError:
            pass
            
    else:
        try:
            ax.plot(T_K_array, Saha[0],'^' , color=colors[i],alpha=0.1, markersize=5)
            ax2.plot(T_K_array, Saha[1]*AU_to_eV,'^' , color=colors[i],alpha=0.1, markersize=5)
        except TypeError:
            pass


# Plot χ0 Line
ax2.plot(T_K_array, np.ones_like(T_K_array)*χ0_AU*AU_to_eV,'-' ,color='k')
ax2.text(np.min(T_K_array)*1.2, 1.01*χ0_AU*AU_to_eV, r"$\chi_0$ = {0:0.1f} [eV]".format(χ0_AU*AU_to_eV), fontsize=12,
        verticalalignment='bottom')#, bbox=props)

# Adding a manual colorbar
sm = plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1))
sm.set_array([])
fig.colorbar(sm, ax=[ax, ax2], orientation='vertical', label=r'$\langle Z\rangle^{\rm initial guess}$')

plt.subplots_adjust(right=0.7)

# text
props = dict(boxstyle='round', facecolor='white', alpha=0.5)
inset_text = f"{element} at n = {n0_invcc:0.2e} [1/cc]"
ax.text(0.15, 0.95, inset_text, transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=props)

ax.set_ylim(1e-7,10)
ax2.set_ylim(1e-3,10*χ0_AU*AU_to_eV)

ax.set_yscale('log')
ax2.set_yscale('log')
ax.legend()
# plt.tight_layout()

# ax.set_yscale('log')
