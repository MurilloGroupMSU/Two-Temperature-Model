# %%
import numpy as np
import matplotlib.pyplot as plt

from constants import *
from physics import JT_GMS_Physics as params

# %%
dens = np.logspace(24, 28) #1/m^3

plt.loglog(dens, params.Fermi_energy(dens)*J_to_eV)
plt.grid(alpha=0.15)
plt.xlabel(r"density [1/m$^3$]")
plt.ylabel("$E_F$ [eV]")
# Out:
# Text(0, 0.5, '$E_F$ [eV]')

# %%
temp = 1e4

plt.semilogx(dens, params.Gamma(dens, temp)*J_to_eV)
plt.grid(alpha=0.15)
plt.xlabel(r"density [1/$m^3$]")
plt.ylabel("$\Gamma$")
plt.title(f"temperature {temp}K")
# Out:
# Text(0.5, 1.0, 'temperature 10000.0K')

# %%
temp = 1e4

plt.semilogx(dens, params.chemical_potential(dens, temp)*J_to_eV)
plt.grid(alpha=0.15)
plt.xlabel(r"density [1/$m^3$]")
plt.ylabel("$\mu$ [eV]")
plt.title(f"temperature {temp} K")
# Out:
# Text(0.5, 1.0, 'temperature 10000.0 K')

# %%
params.electron_thermal_velocity(temp)
# Out:
# 389219.9077893073

# %%
temp = 1e4

plt.semilogx(dens, params.ei_relaxation_time(dens,dens,54*m_p,1,temp,temp)*1e9)
plt.grid(alpha=0.15)
plt.xlabel(r"density [1/$m^3$]")
plt.ylabel(r"$\tau_{ei}$ [ns]")
plt.title(f"temperature {temp}eV")
# Out:
# Text(0.5, 1.0, 'temperature 10000.0eV')

# %%
temp = 1e4

plt.semilogx(dens, params.electron_thermal_conductivity(dens,dens,54*m_p,1,temp,temp)*1e9)
plt.grid(alpha=0.15)
plt.xlabel(r"density [1/$m^3$]")
plt.ylabel(r"$k_e/k_B$ [m$^{-1}$s$^{-1}$]")
plt.title(f"temperature {temp}eV")
# Out:
# Text(0.5, 1.0, 'temperature 10000.0eV')
